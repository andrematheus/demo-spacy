# %%
import spacy
from utils import *

# %%
document = """\
Here is a string with multiple sentences.
I enjoy eating pizza and cheeseburgers.
Though typically not simultaneously.
"""
nlp = spacy.load('en')
doc = nlp(document)

for sentence in doc.sents:
    print('A sentence: {}'.format(sentence))
# Out:
# A sentence: Here is a string with multiple sentences.
#
# A sentence: I enjoy eating pizza and cheeseburgers.
#
# A sentence: Though typically not simultaneously.
